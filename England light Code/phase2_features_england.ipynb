# %% [markdown]
# # Phase-2: Feature Engineering (England_final_light)
#
# **No re-processing needed.** The feature matrix is identical to the England model.
#
# `severity_weighted_count` is present in the feature matrix but is **not included in the Phase 3 FEATURES list**. Removing it from the model is a Phase 3 decision, not a Phase 2 decision the column exists in the data, we simply do not use it as a predictor.
#
# This notebook verifies the England Phase 2 parquet exists and confirms the relevant columns.

# %%
#Importing Libraries
import pandas as pd
from pathlib import Path

# Loading dataset

BASE = Path('Dataset path')
P2   = BASE / 'England' / 'outputs' / 'phase2'

fm = pd.read_parquet(P2 / 'phase2_feature_matrix.parquet')
print(f'Feature matrix shape: {fm.shape}')
print(f'Columns: {list(fm.columns)}')
print(f'\nNote: severity_weighted_count is present but excluded from Phase 3 FEATURES.')
print(f'Phase 2 data source: England/outputs/phase2/')
